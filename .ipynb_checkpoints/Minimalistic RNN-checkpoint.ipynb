# %% [markdown]
# Based on CS231n Lecture 10. For more details see: http://cs231n.stanford.edu/syllabus.html

# %%
import numpy as np

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has {0} characters, {1} unique.'.format(data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    # forward pass
    for t in range(len(inputs)-1):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs)-1)):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-2]

def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while n < 10000:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n {0} \n----'.format(txt, ))

    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0: print('iter {0}, loss: {1}'.format(n, smooth_loss)) # print progress
  
    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                  [dWxh, dWhh, dWhy, dbh, dby], 
                                  [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# data has 63 characters, 62 unique.
# ----
#  1nkV
# nMghYhPT4nT6TjJZFhf4
# KbCMsF795aXO7X7v10vu6OmkiyEly3qE9I5YLRILnEgpyjwo1t5hPkoXRvVKO25
# MkysDp
# qP9ovNLfj2evVwQBs0OvSzYqqMPsJVIGIoEv5mTTJiyqt1zx2lEcXsUqseIXAQ5s5uuJjgyFTDE5zcVtE9hxOn4dC5V3YUcn2D3nm47
# ----
# iter 0, loss: 103.17423499615823
# ----
#  bcdefghOrQRSLEFOHQRKDEFOPIRSsEAWEIRSTUNWHQJKLUIW
# QJmLMAOPsRCTMNOHIRSTMVWHAJKLMNOPIBSDEVWHIJSLMNLHDRCfMNWPQRSLMFWPQJCTMFGPIRKLENOjTRSTUFWHQRKLMNOjQJCLEVOPQWSLMVWHAJSDENOHIRSTMNW
# QBKTUVGHQRmnUVGHIJSDMFO
# ----
# iter 100, loss: 99.13971167838393
# ----
#  bcdefghijklmnopqrstCngxy
# ABCDEFGHIJKLMNOPQRSTUVWCIJKLMVGHIJSLMNOPQRSTUVWPnBSToNWHQJKLMNOPQRefMSijQJKLMVGHARCToVGHIRKLMFGHQJKLMNOPQRCTMVWHIJKLMNOPQRSTUNOHQGSTEFWHIJKLMNOPQRSTUVWHAJKLMNGHIJKLMNOPsRSTMNG
# ----
# iter 200, loss: 90.17824244505329
# ----
#  bcdevwhijklmnopqrstuvwxy
# ABCDEpGHIJKLMNOPQRSTUVWHIJKLMNOPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTEFGHIJKLMNORQRSTUVWPQRSTUVWPQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJSLUVGHIJSLMNOPQRSTUVWPIJKLMNOPIRSTUVW
# ----
# iter 300, loss: 81.70696528138838
# ----
#  bcdefghigklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRCTUVWHIJKLMNOMQRSTUVGHkJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# QRSTUVWHIJKLMNOPQRSTEVWHIJKLMNOPQRSTUVWPIRSTUKL
# ----
# iter 400, loss: 73.9886694507394
# ----
#  bcdefghijklmnopqrstuvrxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSnUVWPQRSTUVWPSJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 500, loss: 66.98493459293171
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPIRSTUVWHIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIJKTMNOPQRSTUVWPIoSTUVWPQRSTUVWPIRSTUVWPIRSTUVW
# ----
# iter 600, loss: 60.63784866356331
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPLRSTUVWHQJKLMNOPQRSTUVWPIRSTUVWPIRSTUVWHIJKLMNO
# ----
# iter 700, loss: 54.888978904200016
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQLSTUVOPQRSTUVWPIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 800, loss: 49.68337442681141
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWPIRKTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJFTMNO
# ----
# iter 900, loss: 44.97046303875913
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRKTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHQJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 1000, loss: 40.70406027519075
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWrIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJCLMNO
# ----
# iter 1100, loss: 36.84213930990928
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJSLMNOPQRSTUVW
# ----
# iter 1200, loss: 33.34652950684348
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHAJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQJSTUVW
# IJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVqHIJKLMNO
# ----
# iter 1300, loss: 30.182602223177437
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIlSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVW
# ----
# iter 1400, loss: 27.318966190095047
# ----
#  bcdefghijklmnopqrstuvwxy
# AJCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUViPIJKLMNOPQRSTUVW
# ----
# iter 1500, loss: 24.72717778466091
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 1600, loss: 22.38147048580296
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQJSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 1700, loss: 20.25850750828082
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQBSTUVWPQJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWPQRSTUVWPIRKTMNO
# ----
# iter 1800, loss: 18.337156295930598
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWPTRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQMSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHAJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHAJKLMNOPQRSTUVW
# ----
# iter 1900, loss: 16.59828288682304
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVW
# ----
# iter 2000, loss: 15.024564673756649
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOHQRSTUVWHIJKLMNO
# ----
# iter 2100, loss: 13.600320172856355
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKTMNOPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWHIEKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNO
# ----
# iter 2200, loss: 12.311354430423886
# ----
#  bcdefghijklmnopqrstuvwxy
# AtCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVW
# ----
# iter 2300, loss: 11.144818745423999
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPkRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 2400, loss: 10.08908345772237
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 2500, loss: 9.133622637035836
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWmIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 2600, loss: 8.268909595010113
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 2700, loss: 7.486322227825348
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# IRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVW
# ----
# iter 2800, loss: 6.778057278029097
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWPIRSTUVWPIJKLMNOPQRSTUVWrIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVW
# ----
# iter 2900, loss: 6.137052683042153
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVW
# ----
# iter 3000, loss: 5.556917254429669
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 3100, loss: 5.031867004118415
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# IJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 3200, loss: 4.55666749787907
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWjhJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 3300, loss: 4.126581672126202
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 3400, loss: 3.7373225999124684
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWMIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 3500, loss: 3.385010738231445
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNO
# ----
# iter 3600, loss: 3.0661352320226065
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 3700, loss: 2.7775188902898527
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVW
# ----
# iter 3800, loss: 2.5162864862463534
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 3900, loss: 2.279836066449652
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 4000, loss: 2.065812983755045
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMhOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 4100, loss: 1.8720863959075889
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVW
# ----
# iter 4200, loss: 1.6967279960107968
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVW
# ----
# iter 4300, loss: 1.53799276321428
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHQJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 4400, loss: 1.3943015419808298
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 4500, loss: 1.2642252764256685
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNO
# ----
# iter 4600, loss: 1.1464707426451033
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNTPQRSTUVWgIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 4700, loss: 1.0398676368288156
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVW
# ----
# iter 4800, loss: 0.9433568904241932
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 4900, loss: 0.8559800958236814
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# IJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVW
# ----
# iter 5000, loss: 0.776869937096091
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 5100, loss: 0.7052415302882894
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 5200, loss: 0.640384586882621
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 5300, loss: 0.5816563221969213
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPARSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVW
# ----
# iter 5400, loss: 0.528475037938754
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 5500, loss: 0.48031431484673176
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 5600, loss: 0.436697757435935
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHQJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 5700, loss: 0.3971942383716462
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQJKLMNO
# ----
# iter 5800, loss: 0.3614135949804318
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVW
# ----
# iter 5900, loss: 0.32900273491944015
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVW
# ----
# iter 6000, loss: 0.2996421121084539
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNO
# ----
# iter 6100, loss: 0.27304253772519804
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWjQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVW
# ----
# iter 6200, loss: 0.248942294409528
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 6300, loss: 0.22710452484951452
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNO
# ----
# iter 6400, loss: 0.20731486866235851
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 6500, loss: 0.18937932396269483
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSLUVWHIJKLMNOPQRSTUVW
# ----
# iter 6600, loss: 0.17312231225491007
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNO
# ----
# iter 6700, loss: 0.1583849273169465
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPNRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPQRSTUVWHQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVW
# ----
# iter 6800, loss: 0.14502335058094254
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWPIRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 6900, loss: 0.13290741717927515
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHAJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVW
# IJKLMNO
# ----
# iter 7000, loss: 0.12191931832971692
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWUIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 7100, loss: 0.11195242709550342
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 7200, loss: 0.10291023578872312
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 7300, loss: 0.0947053944008774
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 7400, loss: 0.08725884045385583
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 7500, loss: 0.08049901157800356
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWPQRSTUVW
# ----
# iter 7600, loss: 0.07436113295054661
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVW
# ----
# iter 7700, loss: 0.06878657247563301
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 7800, loss: 0.06372225726412722
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 7900, loss: 0.05912014558381944
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 8000, loss: 0.05493674900499361
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 8100, loss: 0.051132699967897786
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 8200, loss: 0.047672360452570305
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVBPQRSTUVWHIJKLMNOPQRSTUVWPIJSLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVW
# ----
# iter 8300, loss: 0.044523467842248185
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIWSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 8400, loss: 0.041656814443318854
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVW
# ----
# iter 8500, loss: 0.03904595746118818
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 8600, loss: 0.03666695653588557
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPIRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 8700, loss: 0.03449813621674891
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWrIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 8800, loss: 0.03251987100487367
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWjIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 8900, loss: 0.030714390817656128
# ----
#  bcdefghijklmnopGrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWrIJKLMNOPQRSTUVWHIJKLMNOPQMSTUVWPQRSTUVW
# ----
# iter 9000, loss: 0.029065604933951703
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 9100, loss: 0.027558942663141774
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTEVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 9200, loss: 0.026181209148587275
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVW
# ----
# iter 9300, loss: 0.02492045486721281
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHQJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 9400, loss: 0.023765857523815305
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 9500, loss: 0.02270761516249443
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 9600, loss: 0.021736849429595254
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWrIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWPIRSTUVWHIJKLMNOPQRSTUVWHIJKLMNO
# ----
# iter 9700, loss: 0.020845518023863887
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWPIRSTUVWHIEKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPIRSTUVWPQRSTUVWjIJKLMNOPQRSTUVW
# ----
# iter 9800, loss: 0.020026335461162417
# ----
#  bcdefghijklmnopqrstuvwxy
# ABCDEFGHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPQRSTUVWHIJKLMNOPQRSTUVWPIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVWHIJKLMNOPQRSTUVW
# ----
# iter 9900, loss: 0.01927270136399543
